# %% [markdown]
# <a href="https://colab.research.google.com/github/Marion-Moraa/Marion-Moraa/blob/main/Data_Preparation_Practical.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#importing module
import pandas as pd

# %%
#Uploading the dataset
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-e7595a77-3cdc-49c6-b526-70537788a8f6" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-e7595a77-3cdc-49c6-b526-70537788a8f6">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
#Load the dataset
data = pd.read_csv("sales_data_dirty.csv")

# %%
#View the data
data.head() #Displays rows of the dataset, by default displays the first five rows of the dataset
# Out:
#    OrderID  CustomerName       Product     Category Quantity  Price  \
# 0     1001    John Kamau        Laptop  Electronics        2  75000
# 1     1002  Mary Wanjiku         Mouse  Electronics        5   1500
# 2     1003  Peter Otieno      Keyboard  Electronics      NaN   2500
# 3     1004  Amina Hassan  Office Chair    Furniture        1  12000
# 4     1005  David Mwangi          Desk    Furniture      Two  30000
#
#     OrderDate   Region PaymentMethod
# 0  05/01/2025  Nairobi         Mpesa
# 1  05/01/2025   Nakuru        M-Pesa
# 2  06/01/2025   Kisumu          Cash
# 3  07/01/2025  Mombasa          Card
# 4  08/01/2025  Nairobi         Mpesa

# %%
# Check Dataset structure
print(data.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20 entries, 0 to 19
# Data columns (total 9 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   OrderID        20 non-null     int64
#  1   CustomerName   19 non-null     object
#  2   Product        20 non-null     object
#  3   Category       20 non-null     object
#  4   Quantity       19 non-null     object
#  5   Price          19 non-null     object
#  6   OrderDate      19 non-null     object
#  7   Region         19 non-null     object
#  8   PaymentMethod  20 non-null     object
# dtypes: int64(1), object(8)
# memory usage: 1.5+ KB
# None

# %%
#Investigate the Dataset by running the following commands
data.describe() #gives a quick statistical overview of the dataset's numeric columns
# Out:
#           OrderID
# count    20.00000
# mean   1010.50000
# std       5.91608
# min    1001.00000
# 25%    1005.75000
# 50%    1010.50000
# 75%    1015.25000
# max    1020.00000

# %%
data.isnull() #Checks every cell in the dataset, if a value is missing, it returns True
#if it exists, it returns False
# Out:
#     OrderID  CustomerName  Product  Category  Quantity  Price  OrderDate  \
# 0     False         False    False     False     False  False      False
# 1     False         False    False     False     False  False      False
# 2     False         False    False     False      True  False      False
# 3     False         False    False     False     False  False      False
# 4     False         False    False     False     False  False      False
# 5     False         False    False     False     False  False      False
# 6     False         False    False     False     False  False      False
# 7     False          True    False     False     False  False      False
# 8     False         False    False     False     False  False      False
# 9     False         False    False     False     False  False      False
# 10    False         False    False     False     False  False      False
# 11    False         False    False     False     False  False      False
# ...

# %%
data.isnull().sum() # sum() counts how many True values exist, the missing values
#in each column
# Out:
# OrderID          0
# CustomerName     1
# Product          0
# Category         0
# Quantity         1
# Price            1
# OrderDate        1
# Region           1
# PaymentMethod    0
# dtype: int64

# %%
data.duplicated() #Finds all duplicate values in the dataset, checks each row
#if the row already appeared earlier, it returns True
#if it's the first time the row appears, it returns False
# Out:
# 0     False
# 1     False
# 2     False
# 3     False
# 4     False
# 5     False
# 6     False
# 7     False
# 8     False
# 9     False
# 10    False
# 11    False
# 12    False
# 13    False
# 14    False
# 15    False
# 16    False
# 17    False
# 18    False
# 19    False
# dtype: bool

# %%
data.duplicated().sum() #.sum() counts the number of True values
# Out:
# np.int64(0)

# %%
# Identifying Inconsistent labels
data["Category"].unique()
#data["Category"] selects only the Category column from the dataset.
#the function unique() finds all distinct values in that column, it removes
#duplicates and shows each value only once.
# Out:
# array(['Electronics', 'Furniture', 'Furn.', 'electronic'], dtype=object)

# %%
#Check Payment Method Inconsistencies
data["PaymentMethod"].unique()
# Out:
# array(['Mpesa', 'M-Pesa', 'Cash', 'Card'], dtype=object)

# %%
#Identify Datatype Problems
data["Quantity"].unique()
# Out:
# array(['2', '5', nan, '1', 'Two', '3', '4', '-1', 'four'], dtype=object)

# %%
data["Price"].unique()
# Out:
# array(['75000', '1500', '2500', '12000', '30000', 'KES 70000', '18000',
#        '15000', '28000', '1400', '72000', nan, '71000'], dtype=object)

# %%
#Check invalid dates
data["OrderDate"].unique()
# Out:
# array(['05/01/2025', '06/01/2025', '07/01/2025', '08/01/2025',
#        '09/01/2025', '10/01/2025', '11/01/2025', '12/01/2025',
#        '13/01/2025', '14/01/2025', nan, '2025-13-01', '15/01/2025',
#        '16/01/2025'], dtype=object)

# %%
#Missing region
data["Region"].isnull().sum()
# Out:
# np.int64(1)

# %%
#Find rows with negative quantity
# First, convert 'Quantity' to numeric, coercing errors to NaN
data['Quantity_numeric'] = pd.to_numeric(data['Quantity'], errors='coerce')
# Now, filter for rows where 'Quantity_numeric' is less than 0
data[data['Quantity_numeric'] < 0]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_210/14481085.py in <cell line: 0>()
#       1 #Find rows with negative quantity
# ----> 2 data[data["Quantity"] < 0]
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/ops/common.py in new_method(self, other)
#      74         other = item_from_zerodim(other)
#      75
# ---> 76         return method(self, other)
#      77
#      78     return new_method
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/arraylike.py in __lt__(self, other)
#      46     @unpack_zerodim_and_defer("__lt__")
#      47     def __lt__(self, other):
# ---> 48         return self._cmp_method(other, operator.lt)
#      49
#      50     @unpack_zerodim_and_defer("__le__")
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/series.py in _cmp_method(self, other, op)
# ...
